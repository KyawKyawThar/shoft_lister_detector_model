# %%
import tensorflow as tf
import torch
from ultralytics import YOLO

# %%
print(f"MPS available: {torch.backends.mps.is_available()}")
# Out:
# MPS available: True

# %%
model = YOLO("yolo11n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 41.8MB/s 0.1s.1s<0.0s

# %%
results = model("https://ultralytics.com/images/bus.jpg", device="mps")
results[0].show()
# Out:
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg': 100% ━━━━━━━━━━━━ 134.2KB 4.1MB/s 0.0s
# WARNING ⚠️ NMS time limit 2.050s exceeded
# image 1/1 /Users/kkt/Desktop/shop_lifter_detector/bus.jpg: 640x480 4 persons, 1 bus, 341.2ms
# Speed: 64.7ms preprocess, 341.2ms inference, 710.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
print(tf.__version__)
# Out:
# 2.13.0
